# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("ThrowbackDataThursday Week 11 - Film Genre Stats (1).csv")

# %%
df
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %%
df[['Genre']]
# Out:
#                Genre
# 0          Adventure
# 1          Adventure
# 2          Adventure
# 3          Adventure
# 4          Adventure
# ..               ...
# 295  Multiple Genres
# 296  Multiple Genres
# 297          Reality
# 298          Reality
# 299          Reality
#
# [300 rows x 1 columns]

# %%
df[['Genre','Movies Released','Gross']]
# Out:
#                Genre  Movies Released       Gross
# 0          Adventure               29   771507571
# 1          Adventure               34  1290490033
# 2          Adventure               23   881902843
# 3          Adventure               29  1614467732
# 4          Adventure               27  1612432107
# ..               ...              ...         ...
# 295  Multiple Genres                5     4614134
# 296  Multiple Genres                3     4787450
# 297          Reality                1       16826
# 298          Reality                3      604870
# 299          Reality                1        2027
#
# [300 rows x 3 columns]

# %%
type(df['Year'])
# Out:
# pandas.core.series.Series

# %%
df['Pass'] = df['Year'] + df['Movies Released']
df
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %%
df.drop('Pass',axis=1)
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %%
df.drop(296,axis=0)
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 294    294  Multiple Genres  2016                4     2862219        330890
# 295    295  Multiple Genres  2017                5     4614134        514394
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %%
df
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %%
df.loc[100]
# Out:
# index                                                              100
# Genre                                             Thriller or Suspense
# Year                                                              1999
# Movies Released                                                     17
# Gross                                                        574879882
# Tickets Sold                                                 113165323
# Inflation-Adjusted Gross                                    1015092947
# Top Movie                                              The Sixth Sense
# Top Movie Gross (That Year)                                  276386495
# Top Movie Inflation-Adjusted Gross (That Year)        488028874.387625
# Pass                                                              2016
# Name: 100, dtype: object

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
x = df['Genre']
x
# Out:
# 0            Adventure
# 1            Adventure
# 2            Adventure
# 3            Adventure
# 4            Adventure
#             ...
# 295    Multiple Genres
# 296    Multiple Genres
# 297            Reality
# 298            Reality
# 299            Reality
# Name: Genre, Length: 300, dtype: object

# %%
y = df['Movies Released']
y
# Out:
# 0      29
# 1      34
# 2      23
# 3      29
# 4      27
#        ..
# 295     5
# 296     3
# 297     1
# 298     3
# 299     1
# Name: Movies Released, Length: 300, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'g')

# %%
fig, axes = plt.subplots()
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Changes');

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
